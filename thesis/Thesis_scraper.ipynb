# %% [markdown]
# # Scraping Wellesley College Honor Thesis Data
#
# Author: Andrea Mock

# %%
#import chrome webdriver
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

# %%
import pandas as pd

# import for plotting later
from matplotlib import pyplot as plt
plt.style.use('fivethirtyeight')

# %%
browser = webdriver.Chrome(ChromeDriverManager().install())
browser.get('https://repository.wellesley.edu/collections/thesiscollection?display=grid')
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/andreamock/.wdm/drivers/chromedriver/mac64/87.0.4280.88]

# %%
def getThesisData(index):
    if index == 0:
        browser.get('https://repository.wellesley.edu/collections/thesiscollection?display=grid')
    else:
        browser.get('https://repository.wellesley.edu/collections/thesiscollection?' + 'page=' +str(index) + 'display=grid')
    thesis = browser.find_elements_by_xpath('//div[@class="solr-fields islandora-inline-metadata col-xs-12 col-sm-8 col-md-9"]')
    links = browser.find_elements_by_xpath('//div[@class="fa fa-file-text-o thesis datastream-thumbnail"]/a')
    links_list = [link.get_attribute('href') for link in links]
    return links_list

# %%
def getAllThesisLinks():
    allLinks = []
    for i in range(34):
        currentPage = getThesisData(i)
        allLinks += currentPage
    return allLinks

# %%
allLinks = getAllThesisLinks()

# %%
allLinks[100]
# Out:
# 'https://repository.wellesley.edu/object/ir800'

# %%
browser.get(allLinks[1])

# %%
browser.find_elements_by_xpath('//div[@class="mods-abstract-ms field-value col-xs-8 no-gutter-right"]')[0].text
# Out:
# 'In this work, I examine the case of Japan and how the Japanese state utilized public art museums in the 1980s and early 1990s to shift their national image to that of a "nation-state of culture" (bunka kokka). Museums, especially public ones, are politically implicated institutions. Contrary to their appearance of permanence and insulation, museums are reflective of larger political, economic, and social changes in a society. Drawing upon the theories of Carol Duncan, Pierre Bourdieu, and Tony Bennett, this thesis examines art museums as institutions that facilitate identity and image-formation. Essentially, there are two related types of formations at questions here—the first is how nation-states use museums to shape their national identity and international image, and the second is how individuals form their own social and cultural identity through encounters with the museum. This thesis lies at the intersection of politics, sociology, cultural studies, and museum studies. In this work, I offer a way to unpack and understand the socio-cultural phenomenon of the "museum boom" in Japan in the last three decades of the twentieth century by placing it in the context of the international political implications of museums and framing it as a continuity of Japans national identity and image construction efforts since the Meiji era.'

# %%
def getPageInfo(link):
    """
    given the link for a thesis page, retrieves the data from 
    """
    browser.get(link)
    title = browser.find_elements_by_xpath('//h1[@class="page-header"]')
    author = browser.find_elements_by_xpath('//div[@class="mods-name-personal-creator-namepart-ms field-value col-xs-8 no-gutter-right"]')
    dept = browser.find_elements_by_xpath('//div[@class="mods-name-corporate-department-namepart-ms field-value col-xs-8 no-gutter-right"]')
    date = browser.find_elements_by_xpath('//div[@class="mods-origininfo-type-displaydate-dateother-ms field-value col-xs-8 no-gutter-right"]')
    advisor = browser.find_elements_by_xpath('//div[@class="mods-name-personal-advisor-namepart-ms last field-value col-xs-8 no-gutter-right"]')
    abstract =browser.find_elements_by_xpath('//div[@class="mods-abstract-ms field-value col-xs-8 no-gutter-right"]')
    data_list = [title,author,dept,date,advisor, abstract]
    info_list = []
    for item in data_list:
        try:
            info_list.append(item[0].text)
        except:
            info_list.append(None)
    return info_list

# %%
def saveInformation(links):
    return [getPageInfo(link) for link in links]

# %%
allInformation = saveInformation(allLinks)

# %%
thesis_df = pd.DataFrame(allInformation, columns=['title', 'author', 'dept', 'year','advisor', 'abstract'])
thesis_df
# Out:
#                                                  title              author  \
# 0    Unilateral Friendship Outcomes and Preschool F...         Wong, Maile
# 1    Beyond Prosthetics: the First Steps Towards Id...     Chou, Jacquelyn
# 2    Filling Political Spaces: Iraqi, Humanitarian-...    Seymour, Jillian
# 3    True Fiction: Three Writers' Approaches to Fac...    Krauthamer, Anna
# 4    The Making of a Mountain: Mount Fuji, Miniatur...       Scoble, Emily
# ..                                                 ...                 ...
# 654  Piratical Debauchery, Homesick Sailors, and Na...     Riedler, Pallas
# 655  Experimental investigation of phytoliths and c...  Oppenheim, Georgia
# 656  Synthesis of Canavanine Diamide as a Potential...      Thomas, Vienna
# 657  The Erotics of Imperialism: 5th Century Litera...     Gonzalez, Sarah
# 658  The Failed Emergence of an Anglo-Soviet Cooper...    Miyazaki, Makiko
#
#                                      dept  year  \
# 0                              Psychology  2015
# 1                     Biological Sciences  2015
# 2                       Political Science  2015
# 3                                 English  2015
# 4    East Asian Languages and Literatures  2015
# ..                                    ...   ...
# 654                                 Music  2017
# 655                          Anthropology  2020
# 656                             Chemistry  2020
# 657                     Classical Studies  2020
# 658                     Political Science  2020
#
#                                             advisor  \
# 0                                              None
# 1                                  Suzuki, Yuichiro
# 2                                              None
# 3                                     Chiasson, Dan
# 4                                     Goree, Robert
# ..                                              ...
# 654                          Bhogal, Gurminder Kaur
# 655             Van Arsdale, Adam\nMinor, Elizabeth
# 656            Elmore, Donald E.\nRaines, Ronald T.
# 657  Gilhuly, Kate\nDougherty, Carol\nCain, William
# 658                              Goddard, Stacie E.
#
#                                               abstract
# 0                                                 None
# 1                                                 None
# 2                                                 None
# 3    This thesis examines how three writers challen...
# 4                                                 None
# ..                                                 ...
# 654                                               None
# 655  The Cooking Hypothesis proposes that morpholog...
# 656  Cell-Penetrating Peptides (CPPs) are a promisi...
# 657  Through a literary analysis of Euripides' Hele...
# 658  Between 1933 and 1938, Nazi Germany's recrudes...
#
# [659 rows x 6 columns]

# %%
# save thesis information to csv file 
thesis_df.to_csv('thesis_info.csv')

# %%
thesis_df = pd.read_csv('thesis_info.csv', index_col=0)

# %%
def cleanAdvisor(advisor):
    """
    give a persons advisor data, if the person has multiple advisors returns a list of advisors
    """
    if advisor != None and type(advisor) != float:
        return advisor.split('\n')
    return []

# %%
thesis_df['advisor_clean'] = thesis_df['advisor'].apply(cleanAdvisor)

# %%
list_dept = list(thesis_df['dept'].apply(cleanAdvisor))

# %%
from collections import Counter

# %%
all_dept = [item for sublist in list_dept for item in sublist]

# %%
thesis_dept = pd.DataFrame(Counter(all_dept).most_common(20), columns=['dept','count'])
thesis_dept
# Out:
#                              dept  count
# 0                         English     63
# 1               Political Science     49
# 2                       Economics     48
# 3                       Chemistry     42
# 4                             Art     34
# 5             Biological Sciences     30
# 6                    Neuroscience     30
# 7                      Psychology     29
# 8            Biological Chemistry     28
# 9                     Mathematics     25
# 10                   Anthropology     24
# 11               Computer Science     19
# 12                        Physics     18
# 13                        History     18
# 14                      Sociology     18
# 15                          Music     16
# 16                     Philosophy     15
# 17  Environmental Studies/Science     15
# 18        Media Arts and Sciences     14
# 19              Classical Studies     13

# %%
def plotInfo(dataframe, title, x_axis, plot_color='salmon', hplot=True):
    """
    plots information from a dataframe, with a given color, title and x-axis 
    """

    fig, ax = plt.subplots(figsize=(8, 8))
    
    if hplot == True:
        # Plot horizontal bar graph
        dataframe.sort_values(by='count').plot.barh(x=x_axis,
                      y='count',
                      ax=ax,
                      color=plot_color)
    else:
        dataframe.sort_values(by='count').plot.bar(x=x_axis,
                      y='count',
                      ax=ax,
                      color=plot_color)

    ax.set_title(title)

    plt.show()

# %%
plotInfo(thesis_dept, 'Top Departments with most thesis', 'dept')

# %% [markdown]
# Now we can also take the distribution of thesis by year:

# %%
#unique years 
thesis_df['year'].unique()
# Out:
# array([2015, 2016, 2017, 2018, 2012, 2014, 2019, 2020, 2013, 1994])

# %%
# thesis by year
thesisByYear = pd.DataFrame(thesis_df['year'].value_counts())
thesisByYear
# Out:
#       year
# 2016    84
# 2012    84
# 2014    79
# 2013    78
# 2017    73
# 2015    73
# 2018    68
# 2019    63
# 2020    56
# 1994     1

# %% [markdown]
# Now lets not just take a look at the years but also the computer science thesis and advisors:

# %%
# number of unique advisors
len(thesis_df['advisor'].unique())
# Out:
# 408

# %%
# most popular advisors 
pd.DataFrame(Counter(thesis_df['advisor']).most_common(20)[1:], columns=['advisor','count'])
# Out:
#                  advisor  count
# 0       Suzuki, Yuichiro      7
# 1         Quintana, Ryan      7
# 2    Wall-Randell, Sarah      6
# 3      Armstrong, Justin      6
# 4         Sides, Marilyn      6
# 5   Rutherford, Markella      6
# 6       Turbak, Franklyn      6
# 7         Hickey, Alison      5
# 8          Cain, William      5
# 9          Murphy, Craig      4
# 10       Goddard, Stacie      4
# 11        Grattan, Laura      4
# 12           Hajj, Nadya      4
# 13            Burke, Tom      4
# 14         Datta, Venita      4
# 15      Haines, David R.      4
# 16         Chiasson, Dan      3
# 17          Olsen, David      3
# 18       Flynn, Nolan T.      3

# %%
# all CS Thesis
cs_thesis = thesis_df[thesis_df['dept'] == 'Computer Science']
cs_thesis
# Out:
#                                                  title  \
# 18   Privacy Implications of New York City's Stop-a...
# 106  Evaluation of Dynamic Binary Instrumentation A...
# 110  adVantage -- Seeing the Universe: How Virtual ...
# 177         Computational Thinking and Technology Toys
# 212  Suggested Blocks: Using Neural Networks To Aid...
# 261  The Challenges of Algorithmically Assigning Fa...
# 296  The Design and Implementation of Venbrace, a T...
# 301  Where Political News and Algorithms Meet: A Lo...
# 311  Spatio-Temporal Analysis and Simulation of Hum...
# 398  Improving the Usability of App Inventor throug...
# 403           Improving App Inventor Debugging Support
# 540  Tutor-Complete: An Educational Game and Intell...
# 601  Developing and Assessing New List Operators in...
# 602  Folders: A Visual Organization System for MIT ...
# 640  Device Dash: Designing, Implementing, and Eval...
# 644  Representing Expressive Types in Blocks Progra...
# 645  Sound Thread Local Analysis for Lockset-Based ...
#
#                      author              dept  year  \
# 18       Manfredi, Veronica  Computer Science  2015
# 106           Zhao, Valerie  Computer Science  2018
# 110           McNair, Eliza  Computer Science  2018
# 177         Lin, Veronica J  Computer Science  2015
# 212  Svanberg, Maja Susanna  Computer Science  2018
# 261             Lurie, Emma  Computer Science  2019
# 296     Huang, Ruanqianqian  Computer Science  2020
# 301   Umarova, Khonzodakhon  Computer Science  2020
# 311              Li, Huihan  Computer Science  2020
# 398        Chadha, Karishma  Computer Science  2014
# 403       Okerlund, Johanna  Computer Science  2014
# 540        Kjeer, Katherine  Computer Science  2016
# 601             Kim, Soojin  Computer Science  2015
# 602                Lu, Xixi  Computer Science  2015
# 640            Vuksani, Era  Computer Science  2012
# 644            Vasek, Marie  Computer Science  2012
# 645       Mincheva, Samuila  Computer Science  2017
#
#                                               advisor  \
# 18                                    Mir, Darakhshan
# 106                                 Wood, Benjamin P.
# 110        Anderson, Scott D.\nWatters, Wesley Andrés
# 177                                       Shaer, Orit
# 212                                  Turbak, Franklyn
# 261                                   Mustafaraj, Eni
# 296                                  Turbak, Franklyn
# 301                                   Mustafaraj, Eni
# 311                                 Bassem, Christine
# 398                                  Turbak, Franklyn
# 403                                  Turbak, Franklyn
# 540                                   Mustafaraj, Eni
# 601                                  Turbak, Franklyn
# 602  Turbak, Franklyn\nTjaden, Brian\nMustafaraj, Eni
# 640       Moore, Tyler\nLippmann, Richard\nYu, Tamara
# 644                                  Turbak, Franklyn
# 645                                 Wood, Benjamin P.
#
#                                               abstract  \
# 18   A wider release of police datasets could enabl...
# 106  From web browsing to bank transactions, to dat...
# 110  This thesis introduces the "adVantage - Seeing...
# 177  Computational thinking is an increasingly popu...
# 212  MIT App Inventor is a programming environment ...
# 261  In the era of misinformation and machine learn...
# 296  Blocks programming environments (BPEs) lower b...
# 301  Over the years, Google has become a very impor...
# 311  With the rapid development of mobile technolog...
# 398  In blocks programming, users compose programs ...
# 403  MIT App Inventor 2 (AI2) is a visual environme...
# 540  Educational games and Intelligent Tutoring Sys...
# 601  MIT App Inventor is a blocks-based programming...
# 602  In blocks programming languages, such as MIT A...
# 640                                                NaN
# 644  In blocks programming languages, such as Scrat...
# 645  Multithreading is a powerful model of parallel...
#
#                                          advisor_clean
# 18                                   [Mir, Darakhshan]
# 106                                [Wood, Benjamin P.]
# 110       [Anderson, Scott D., Watters, Wesley Andrés]
# 177                                      [Shaer, Orit]
# 212                                 [Turbak, Franklyn]
# 261                                  [Mustafaraj, Eni]
# 296                                 [Turbak, Franklyn]
# 301                                  [Mustafaraj, Eni]
# 311                                [Bassem, Christine]
# 398                                 [Turbak, Franklyn]
# 403                                 [Turbak, Franklyn]
# 540                                  [Mustafaraj, Eni]
# 601                                 [Turbak, Franklyn]
# 602  [Turbak, Franklyn, Tjaden, Brian, Mustafaraj, ...
# 640      [Moore, Tyler, Lippmann, Richard, Yu, Tamara]
# 644                                 [Turbak, Franklyn]
# 645                                [Wood, Benjamin P.]

# %%
csThesisCounter = Counter(cs_thesis['year'])
csThesisCounter
# Out:
# Counter({2015: 4,
#          2018: 3,
#          2019: 1,
#          2020: 3,
#          2014: 2,
#          2016: 1,
#          2012: 2,
#          2017: 1})

# %% [markdown]
# We are also interested in exploring what the topics are that students write their thesis about. To do so we create a wordCloud of words included in a students abstract.

# %%
def createAbstractString(all_thesis):
    thesisString = ''
    for thesis in all_thesis:
        if thesis != None and type(thesis) != float:
            thesisString += " " + thesis
    return thesisString

# %%
thesisString = createAbstractString(cs_thesis['abstract'])
thesisString[:100] # string with all abstract descritions
# Out:
# ' A wider release of police datasets could enable social scientists, community activists, and civil l'

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt

# %%
def updateStopWords(lang, wordSet=set()):
    """ 
     takes two parameters, the name of a language and a set of additional stopwords we would like to consider
    """
    stopwords = nltk.corpus.stopwords.words(lang)
    newStopWords = wordSet
    stopwords.extend(wordSet)
    return stopwords

# %%
def createWordCloud(text, stopwords, widthImg, heightImg, backgroundCol, colormap):
    """
     takes several parameters: the text as a string, the set of stopwords, 
     the filename to save the wordcloud image, the size of the image (width and height), 
     max number of words, background color, and a colormap. 
     The function displays the wordcloud and saves it as a PNG file.
    """
    wordcloud = WordCloud(width = widthImg, height = heightImg, 
                background_color =backgroundCol, 
                stopwords = stopwords, colormap = colormap,
                min_font_size = 10).generate(text) 
    # plot the WordCloud image                        
    plt.figure(figsize = (8, 8), facecolor = None) 
    plt.imshow(wordcloud) 
    plt.axis("off") 
    plt.tight_layout(pad = 0) 
    plt.show()

# %%
createWordCloud(thesisString, STOPWORDS, 700, 700, 'white', "twilight")

# %% [markdown]
# We can also look at the thesis topics and see if there are different words that pop up in a wordcloud:

# %%
thesisTitleString = createAbstractString(cs_thesis['title'])
thesisTitleString[:200]
# Out:
# " Privacy Implications of New York City's Stop-and-Frisk Data Evaluation of Dynamic Binary Instrumentation Approaches: Dynamic Binary Translation vs. Dynamic Probe Injection adVantage -- Seeing the Uni"

# %%
createWordCloud(thesisTitleString, STOPWORDS, 800, 800, 'white', "twilight")
